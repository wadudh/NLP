# %% [markdown]
# <table align="left" width=100%>
#     <tr>
#         <td width="20%">
#             <img src="faculty.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                   <b> Assignment Questions </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# Total Marks: 30
# ## URL for Ecommerce Site:
#
# https://www.amazon.in/

# %% [markdown]
# 1. Import Libraries (2 Marks)
# 2. Use the above URL to scrape product links from product listing pages (3 Marks)
# 3. Scraping of "laptop" data from individual product pages (5 Marks)
# 4. Construct csv file which includes following information (10 Marks)
#                          a. Product title
#                          b. Price
#                          c. Model
#                          d. Star rating
# 5. Create a corpus with 10 sample sentences. Perform Parts of Speech (POS) Tagging for the sentences in the corpus. (4 Marks)
# 6. Find the Named Entity Recognition (NER) for the same corpus. (3 Marks)
# 7. Find the top 5 results for the following equation using Word2Vec Model
# "Einstein - Scientist + Picasso = ?" (3 Marks)

# %% [markdown]
# ### Question#1

# %%
# !pip install BeautifulSoup4

# %%
# !pip3 install pip  gensim

# %%
# !pip3 install nltk

# %%
# !python -m spacy download en
# Out:
# ...
# [!] As of spaCy v3.0, shortcuts like 'en' are deprecated. Please use the full
# pipeline package name 'en_core_web_sm' instead.
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# !pip3 install spacy

# %%
import requests #The requests module allows to send HTTP requests 
from bs4 import BeautifulSoup #library for pulling data out of HTML and XML files
import gensim.downloader as api #This module is an API for downloading, getting information and loading datasets/models.
import csv #Libarary to create and write data in CSV file
import nltk #Natural Language Toolkit - to preprocess the data 
import spacy #helps to build applications that process and “understand” large volumes of text

# %% [markdown]
# ### Question#2

# %% [markdown]
# 2.Use the above URL to scrape product links from product listing pages (3 Marks)

# %%
# Making a GET request and making SSl certificate valiation as False
req = requests.get('https://www.amazon.in/', verify=False)
content = req.content
# Parsing the HTML
soup = BeautifulSoup(content, 'html.parser')
# To view whether we have actually acquired amazon html data or amazon has blocked the request
print(content)
# Out:
# C:\Users\epalanisamy.YODLEE\Anaconda3\envs\sample\lib\site-packages\urllib3\connectionpool.py:988: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.amazon.in'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# ...

# %%
# find all the anchor tags with "href"
for link in soup.find_all('a'):
    if (link.get('href')) != None:
        if 'https://' in (link.get('href')):
            print(link.get('href'))
#Written a condition which checks and prints only https:// urls and not amazon local redirection url
# Out:
# https://www.amazon.in/ap/signin?openid.pape.max_auth_age=0&openid.return_to=https%3A%2F%2Fwww.amazon.in%2F%3F_encoding%3DUTF8%26ref_%3Dnav_ya_signin&openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&openid.assoc_handle=inflex&openid.mode=checkid_setup&openid.claimed_id=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&openid.ns=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0&
# https://www.amazon.in/gp/cart/view.html?ref_=nav_cart
# https://www.aboutamazon.in/?utm_source=gateway&utm_medium=footer
# https://amazon.jobs
# https://press.aboutamazon.in/?utm_source=gateway&utm_medium=footer
# https://www.amazon.science
# https://www.amazon.in/gp/redirect.html/ref=footer_fb?location=http://www.facebook.com/AmazonIN&token=2075D5EAC7BB214089728E2183FD391706D41E94&6
# https://www.amazon.in/gp/redirect.html/ref=footer_twitter?location=http://twitter.com/AmazonIN&token=A309DFBFCB1E37A808FF531934855DC817F130B6&6
# ...

# %% [markdown]
# ### Question#3

# %% [markdown]
# Since amazon url is blocking afer 2-3 attempts of scraping, using flipkart url

# %%
r_individual = requests.get('https://www.flipkart.com/lenovo-ideapad-3-core-i3-11th-gen-8-gb-512-gb-ssd-windows-11-home-82h801l7in-82h802fjin-82h802l3in-82h801lhin-thin-light-laptop/p/itm0e009f57a591b?pid=COMG9VHHG6Q3RRJX&lid=LSTCOMG9VHHG6Q3RRJXQHPK6Q&marketplace=FLIPKART&q=laptop&store=6bo%2Fb5g&srno=s_1_1&otracker=search&otracker1=search&fm=organic&iid=en_Nf07GwGG9VIGC%2FQmdLy6K87eoxn1lnMoSuBeoDRQPmMGYpuWbgLoZSvcItV7mqBR87N8Qo4v54HBhNQIb4Wspw%3D%3D&ppt=hp&ppn=homepage&ssid=g31fd1x0dc0000001671886164752&qH=312f91285e048e09',verify=False)
individual_content = r_individual.content
# Parsing the HTML
soup_individual = BeautifulSoup(individual_content, 'html.parser')
#A single laptop Technical description has be parsed
# Out:
# C:\Users\epalanisamy.YODLEE\Anaconda3\envs\sample\lib\site-packages\urllib3\connectionpool.py:988: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.flipkart.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %%
print(individual_content)
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.c46047.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x5
# ...

# %%
#print(r.content)
v_individual = soup_individual.find('table',class_="_14cfVK")
#v_individual = soup_individual.find('table',class_="_14cfVK")
#print(v)
#print(v.text)

# %%
for link in v_individual.find_all('tr'):
    print("--------------------")
    #print(link)
    desc_title = link.find('td',class_="_1hKmbr col col-3-12")
    print(desc_title.text)
    desc_body = link.find('li',class_="_21lJbe")
    print(desc_body.text)
#Technical Description of a single Laptop
# Out:
# --------------------
# Sales Package
# Laptop, Power Adaptor, User Guide, Warranty Documents
# --------------------
# Model Number
# 82H801L7IN | 82H802FJIN | 82H802L3IN | 82H801LHIN
# --------------------
# Part Number
# 0196118455495 | 0196379293072 | 0196800313836 | 0196118455235
# --------------------
# Model Name
# 15ITL6
# --------------------
# Series
# IdeaPad 3
# --------------------
# Color
# Arctic Grey
# --------------------
# Type
# Thin and Light Laptop
# --------------------
# Suitable For
# Processing & Multitasking
# --------------------
# Battery Backup
# Upto 12 hours
# --------------------
# MS Office Provided
# Yes

# %% [markdown]
# ### Question#4

# %%
r_csv = requests.get('https://www.flipkart.com/search?q=laptop&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY',verify=False)
csv_content = r_csv.content
# Parsing the HTML
soup_csv = BeautifulSoup(csv_content, 'html.parser')
# Out:
# C:\Users\epalanisamy.YODLEE\Anaconda3\envs\sample\lib\site-packages\urllib3\connectionpool.py:988: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.flipkart.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %%
print(soup_csv)
# Out:
# <!DOCTYPE html>
# ...

# %%
csv_file = open('product_detail.csv', 'w', encoding='utf-8') 
csv_writer = csv.writer(csv_file) 
csv_writer.writerow(['Product Title', 'Price', 'Model', 'Star rating'])
layer_one = soup_csv.find('div',class_="_1YokD2 _3Mn1Gg")
#print(layer_one)
k = 0
for link_csv in layer_one.find_all('div',class_="_1AtVbE col-12-12"):
    if k < 24:
        print("----------Next----------")
        #print(link)
        desc_model = link_csv.find('div',class_="_4rR01T")
        print(desc_model.text)
        desc_rating = link_csv.find('div',class_="_3LWZlK")
        if desc_rating != None:
            rating_ = desc_rating.text
        else:
            rating_ = "None"

        desc_price = link_csv.find('div',class_="_30jeq3 _1_WHN1")
        print(desc_price.text)
        csv_writer.writerow(['Laptop',desc_price.text,desc_model.text,rating_])
        k=k+1
    else:
        break
csv_file.close()
# Out:
# ----------Next----------
# RedmiBook Pro Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) Thin and Light Laptop
# ₹42,290
# ----------Next----------
# acer Aspire 3 Ryzen 3 Dual Core 3250U - (8 GB/256 GB SSD/Windows 11 Home) A315-23 Laptop
# ₹24,990
# ----------Next----------
# ASUS VivoBook 15 (2022) Core i3 10th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515JA-EJ362WS | X515JA-E...
# ₹33,990
# ----------Next----------
# HP Pavilion Ryzen 5 Hexa Core AMD R5-5600H - (8 GB/512 GB SSD/Windows 10/4 GB Graphics/NVIDIA GeForce ...
# ₹54,990
# ----------Next----------
# APPLE 2020 Macbook Air M1 - (8 GB/256 GB SSD/Mac OS Big Sur) MGN63HN/A
# ₹86,990
# ----------Next----------
# Lenovo IdeaPad 3 Celeron Dual Core - (8 GB/256 GB SSD/Windows 11 Home) 81WQ00MQIN|81WQ00NXIN Laptop
# ₹26,478
# ----------Next----------
# ASUS Vivobook 15 Core i5 11th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515EA-EJ522WS Thin and Light La...
# ₹46,990
# ----------Next----------
# ...

# %% [markdown]
# ### Question#5

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\epalanisamy.YODLEE\AppData\Roaming\nltk_data.
# [nltk_data]     ..
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\epalanisamy.YODLEE\AppData\Roaming\nltk_data.
# [nltk_data]     ..
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# True

# %%
text = "I love eating apples. She goes to the store every day. He bought a new car last week. They are playing football in the park. She has been working on her project for two months. We need to finish the report today. The dog barked at the postman. The cat meowed at the mouse. I will be visiting my grandmother tomorrow. We can watch a movie after dinner."
#Text variable contains 10 samples
tokens = nltk.word_tokenize(text)
tagged = nltk.pos_tag(tokens)

print(tagged)
# Out:
# [('I', 'PRP'), ('love', 'VBP'), ('eating', 'VBG'), ('apples', 'NNS'), ('.', '.'), ('She', 'PRP'), ('goes', 'VBZ'), ('to', 'TO'), ('the', 'DT'), ('store', 'NN'), ('every', 'DT'), ('day', 'NN'), ('.', '.'), ('He', 'PRP'), ('bought', 'VBD'), ('a', 'DT'), ('new', 'JJ'), ('car', 'NN'), ('last', 'JJ'), ('week', 'NN'), ('.', '.'), ('They', 'PRP'), ('are', 'VBP'), ('playing', 'VBG'), ('football', 'NN'), ('in', 'IN'), ('the', 'DT'), ('park', 'NN'), ('.', '.'), ('She', 'PRP'), ('has', 'VBZ'), ('been', 'VBN'), ('working', 'VBG'), ('on', 'IN'), ('her', 'PRP$'), ('project', 'NN'), ('for', 'IN'), ('two', 'CD'), ('months', 'NNS'), ('.', '.'), ('We', 'PRP'), ('need', 'VBP'), ('to', 'TO'), ('finish', 'VB'), ('the', 'DT'), ('report', 'NN'), ('today', 'NN'), ('.', '.'), ('The', 'DT'), ('dog', 'NN'), ('barked', 'VBD'), ('at', 'IN'), ('the', 'DT'), ('postman', 'NN'), ('.', '.'), ('The', 'DT'), ('cat', 'NN'), ('meowed', 'VBD'), ('at', 'IN'), ('the', 'DT'), ('mouse', 'NN'), ('.', '.'), ('I', 'PRP'), ('will
# ...

# %% [markdown]
# ### Question#6

# %%
nlp = spacy.load("en_core_web_sm")


doc = nlp(text)

for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# last week DATE
# two months DATE
# today DATE
# tomorrow DATE

# %%
model = api.load('word2vec-google-news-300')
results = model.most_similar(positive=['Einstein', 'Picasso'], negative=['Scientist'], topn=5)

for result in results:
    print(result[0])
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded
# Pablo_Picasso
# Rembrandt
# Degas
# Matisse
# Salvador_Dalí
